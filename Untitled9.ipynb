# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
iowa_file_path =r"C:\Users\Hardik Shrivastava\Downloads\train.csv"

# %%
home_data = pd.read_csv(iowa_file_path)
print (home_data)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
y = home_data.SalePrice
list(home_data)
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']

# %%
X = home_data[features]

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# %%
iowa_model = DecisionTreeRegressor(random_state=1)

# %%
iowa_model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
val_predictions = iowa_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("Validation MAE: {:,.0f}".format(val_mae))
# Out:
# Validation MAE: 29,653

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex5 import *
print("\nSetup complete")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-caa45035827e> in <module>
# ----> 1 from learntools.core import binder
#       2 binder.bind(globals())
#       3 from learntools.machine_learning.ex5 import *
#       4 print("\nSetup complete")
#
# ModuleNotFoundError: No module named 'learntools'

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)
def get_pred(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    return(preds_val)

# %%
candidate_max_leaf_nodes = [5, 25, 50, 100,110, 250, 500]
import matplotlib.pyplot as plt
import numpy as np

# %%
for max_leaf_nodes in [5, 25, 50, 100,105,106,107,250, 500]:
    my_mae= get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    pred=get_pred(max_leaf_nodes, train_X, val_X, train_y, val_y)
    plt.figure()
    plt.plot(pred,val_y)
    plt.show()
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  35044
# Max leaf nodes: 25  		 Mean Absolute Error:  29016
# Max leaf nodes: 50  		 Mean Absolute Error:  27405
# Max leaf nodes: 100  		 Mean Absolute Error:  27282
# Max leaf nodes: 105  		 Mean Absolute Error:  27171
# Max leaf nodes: 106  		 Mean Absolute Error:  27215
# Max leaf nodes: 107  		 Mean Absolute Error:  27362
# Max leaf nodes: 250  		 Mean Absolute Error:  27893
# Max leaf nodes: 500  		 Mean Absolute Error:  29454

# %%
final_model = DecisionTreeRegressor(max_leaf_nodes=105,random_state=0)

# %%
final_model.fit(X,y)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=105, random_state=0)

# %%
predict=final_model.predict(val_X)

# %%
 mae = mean_absolute_error(val_y, predict)

# %%
print(mae)
# Out:
# 16635.867089506868
